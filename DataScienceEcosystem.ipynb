# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# * List popular languages for Data Science.
# * List the libraries most commonly used by data scientists.
# * List data science tools.
# * Run through some examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java Script
# 5. TypeScript
# 6. Visual Basic.NET

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. TensorFlow
# 6. PyTorch
# 7. Keras
# 8. Scikit-learn

# %% [markdown]
# ### Data Science Tools
#
# 1. PostgreSQL
# 2. Jupyter
# 3. RStudio
# 4. Visual Studio
# 5. Anaconda Navigator
# 6. Kibana
# 7. PixieDust

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# _This a simple arithmetic expression to mutiply then add integers._

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# _This will convert 200 minutes to hours by diving by 60._

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author

# %% [markdown]
# Lucas Silva Castro
